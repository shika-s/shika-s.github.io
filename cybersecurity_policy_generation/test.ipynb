# %%
from policy_framework_mapper import *

# %%
get_framework_context_for_policy(framework_name="NIST CSF", policy_name="Asset Management Policy")
# Out:
# {'framework': 'NIST CSF',
#  'policy': 'Asset Management Policy',
#  'controls': [{'control_area': 'Asset Management (ID.AM)',
#    'subcontrols': [{'id': 'ID.AM-1',
#      'name': 'Device and System Management (ID.AM-1)'},
#     {'id': 'ID.AM-4', 'name': 'External Information Systems (ID.AM-4)'},
#     {'id': 'ID.AM-5', 'name': 'Resources Classification (ID.AM-5)'},
#     {'id': 'ID.AM-2',
#      'name': 'Software and Applications Management (ID.AM-2)'}]},
#   {'control_area': 'Data Security (PR.DS)',
#    'subcontrols': [{'id': 'PR.DS-3', 'name': 'Asset Management (PR.DS-3)'}]},
#   {'control_area': 'Information Protection Processes and Procedures (PR.IP)',
#    'subcontrols': [{'id': 'PR.IP-5',
#      'name': 'Physical Operating Environment (PR.IP-5)'}]}]}
