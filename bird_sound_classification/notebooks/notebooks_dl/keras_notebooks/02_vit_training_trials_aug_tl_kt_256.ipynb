# %% [markdown]
# **Overview of `02_vit_training_trials_aug_tl_kt_256.ipynb`**
#
# This notebook conducts an end-to-end investigation of Vision Transformer (ViT)–based classification for the BirdCLEF-2025 challenge, combining spectrogram inputs with metadata and Keras Tuner–driven hyperparameter optimization. It is organized as follows:
#
# 1. **Configuration & Flags**
#
#    * Selector switches control augmentation, transfer learning, class weights, and tuner usage
#    * Core parameters (input resolution, batch size, learning-rate bounds, number of folds, etc.) are defined up front
#
# 2. **Data Loading & Preprocessing**
#
#    * Load precomputed mel-spectrogram arrays
#    * Extract, scale, and one-hot encode geospatial and behavioral metadata
#    * Build balanced training and validation splits, compute oversampling caps and class weights
#
# 3. **Hyperparameter Search**
#
#    * Define a search space for learning rate, dropout rate, backbone-unfreeze schedule, and weight decay
#    * Run a Hyperband search to identify the optimal combination
#    * Persist the best hyperparameters for downstream experiments
#
# 4. **Cross-Validation with Best Hyperparameters**
#
#    * Apply 5-fold stratified cross-validation using the previously found settings
#    * Aggregate fold-level metrics (best epoch, loss, accuracy, macro-F1) into a summary table
#
# 5. **Final Model Evaluation**
#
#    * Retrain on full training set with best hyperparameters
#    * Evaluate on held-out test data, reporting confusion matrices, per-class F1 scores, and probability distributions
#
# 6. **Key Notes & Best Practices**
#
#    * ViT models require careful VRAM management; freezing backbone often preserves generalization
#    * Oversampling capped at 50× plus on-the-fly spectrogram masking consistently outperforms heavy class-weighting
#    * Custom callbacks unfreeze the transformer backbone after a user-defined number of epochs without manual intervention
#
# 7. **Extensions & Customization**
#
#    * Easily swap in alternative backbones (e.g. EfficientNet) or add additional audio channels (Chroma, MFCC)
#    * Tweak augmentation pipelines or incorporate attention mechanisms in metadata fusion

# %%
# Import common modules and set global configs
from project_utils.common_imports import *

# Specific imports for data, augmentation, model, and evaluation
from project_utils.loading_utils import main_data_processing_pipeline, preprocess_metadata
from project_utils.data_augmentor_and_generator import data_generator, data_generator_with_metadata, SpecTimeMask, SpecFreqMask, get_steps
from project_utils.model_architect import get_vit_model, macro_f1_fn, categorical_focal_loss, UnfreezeBackbone, get_cosine_decay_scheduler, AddClsToken, SafeCheckpointTuner, get_multimodal_vit_model
from project_utils.tuner_utils import run_multimodal_tuner
from project_utils.cv_utils import cross_validate_best_hp
from project_utils.evaluation_utils import evaluate_on_test, evaluate_on_test_multimodal, plot_training_diagnostics, plot_test_evaluation, CLASS_MAPPING_DICT

# System info
print(f"TensorFlow version: {tf.__version__}")
print(f"GPUs available: {len(tf.config.list_physical_devices('GPU'))}")

os.environ["TF_GPU_ALLOCATOR"] = "cuda_malloc_async"
# Out:
# 2025-08-07 09:53:53.074118: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-07 09:53:53.089709: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754585633.105266 2085687 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754585633.109942 2085687 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1754585633.121816 2085687 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754585633.121830 2085687 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754585633.121832 2085687 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1754585633.121833 2085687 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-08-07 09:53:53.126077: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# TensorFlow version: 2.19.0
# GPUs available: 1

# %%
class CFG:
    # ─── Static defaults ────────────────────────────────────────────────────────
    seed = 42
    debug = False
    print_freq = 10000
    num_workers = 1

    # Parametric settings
    model_type = "vit" # vit or rescnn
    input_dim = 256             # can be 32, 64, 256, etc.
    train_model = True
    use_augmentation   = True
    use_oversampling   = False
    use_class_weights  = True
    use_transfer_learning = True
    use_tuner = True

    # Training hyperparams
    epochs = 15  # Increase for main training; tuner will use up to this
    batch_size   = 8
    lr           = 8.24e-4  # Tuned value (rounded from 0.000824)
    weight_decay = 7.55e-6  # Tuned value (rounded from 7.55e-6)
    min_lr       = 1e-6
    dropout_rate = 0.2

    # Cross-validation
    n_fold         = 5

    # Model / data specifics
    in_channels = 1
    num_classes = 4
    freeze_epochs = 0

    # Augmentation params (adjusted dynamically below)
    noise_std      = 0.1
    max_time_shift = 0.2
    max_freq_shift = 0.2
    max_mask_time  = 0.15
    max_mask_freq  = 0.15

    # Metadata features
    metadata_dim = 15

    # ─── Paths ───────────────────────────────────────────────────────────────────
    PROJECT_ROOT_DIR = Path.cwd().parents[2]
    OUTPUT_DIR       = PROJECT_ROOT_DIR / "data/working"
    SPECTROGRAMS_DIR = OUTPUT_DIR / "birdclef25-mel-spectrograms"

    working_df_path  = PROJECT_ROOT_DIR / "data/raw/downsampled_metadata.csv"

    MODELS_DIR     = OUTPUT_DIR / "models"
    PLOTS_DIR      = OUTPUT_DIR / "plots"
    RESULTS_CSV_DIR= OUTPUT_DIR / "result_csvs"

    # ─── Initialization ──────────────────────────────────────────────────────────
    def __init__(self):

        # Minimal seed setting
        os.environ['PYTHONHASHSEED'] = str(self.seed)  # For hash consistency (e.g., dict ordering)
        random.seed(self.seed)                         # Python random
        np.random.seed(self.seed)                      # NumPy random
        tf.random.set_seed(self.seed)                  # TensorFlow/Keras global seed

        # 1) Create dirs
        for d in (self.MODELS_DIR, self.PLOTS_DIR, self.RESULTS_CSV_DIR):
            os.makedirs(d, exist_ok=True)

        # 2) Fix augmentation-dependent params
        if self.use_augmentation:
            self.aug_prob    = 1
            self.mixup_alpha = 0.2

            # Set size-specific augmentation params
            if self.input_dim == 32:
                self.noise_std      = 0.065
                self.max_time_shift = 0.11
                self.max_freq_shift = 0.065
                self.max_mask_time  = 0.125
                self.max_mask_freq  = 0.1
            elif self.input_dim == 64:
                self.noise_std      = 0.09
                self.max_time_shift = 0.135
                self.max_freq_shift = 0.09
                self.max_mask_time  = 0.175
                self.max_mask_freq  = 0.135
            else:
                # Fallback for other sizes (e.g., 256); use 64x64 values
                self.noise_std      = 0.09
                self.max_time_shift = 0.135
                self.max_freq_shift = 0.09
                self.max_mask_time  = 0.175
                self.max_mask_freq  = 0.135

        # 3) Set target shape (unchanged)
        self.TARGET_SHAPE = (self.input_dim, self.input_dim)


        # ─── Derived properties ─────────────────────────────────────────────────────
    @property
    def spectrogram_npy(self):
        return self.SPECTROGRAMS_DIR / f"birdclef2025_melspec_5sec_{self.input_dim}_{self.input_dim}.npy"

    @property
    def model_save_name(self):
        suffix = ""
        if self.use_augmentation:      suffix += "_aug"
        if self.use_oversampling:      suffix += "_os"
        if self.use_class_weights:     suffix += "_cw"
        if self.use_transfer_learning: suffix += "_tl"
        if self.model_type.lower() == "vit":
            return f"vit_model_{self.input_dim}{suffix}.keras"
        elif self.model_type.lower() == "rescnn":
            return f"rescnn_model_{self.input_dim}{suffix}.keras"
        else:
            raise ValueError(f"Unsupported model type: {self.model_type}. Use 'vit' or 'rescnn'.")

cfg = CFG()

# %%
f'best_{cfg.model_save_name}'
# Out:
# 'best_vit_model_256_aug_cw_tl.keras'

# %%
# Load pre-computed mel spectrograms
spectrograms = np.load(cfg.spectrogram_npy, allow_pickle=True).item()
print(f"Loaded {len(spectrograms)} pre-computed mel spectrograms")
print(f"Example spectrogram shape: {spectrograms['1139490-CSA36389'].shape}")
# Out:
# Loaded 28564 pre-computed mel spectrograms
# Example spectrogram shape: (256, 256)

# %%
# Run the main pipeline to load data, compute factors/weights, and inspect
combined_train_val_df, test_df, class_weights_dict, filtered_spectrograms = main_data_processing_pipeline(
    cfg, spectrograms, data_generator
)

# For generator usage
class_weights = class_weights_dict if cfg.use_class_weights else None

metadata_features = preprocess_metadata(combined_train_val_df, cfg)

# Manage memory usage
del spectrograms
gc.collect()

display(combined_train_val_df.head(3))  # Display first 3 rows for inspection
# Out:
# Loading full dataset...
# Train/Val samples: 332
# Test samples: 68
# Filtered spectrograms to 400 entries
# Class counts in train/val: {0: 87, 1: 84, 2: 81, 3: 80}
# Computed oversampling factors: {0: 1, 1: 1, 2: 1, 3: 1}
#
# Full dataset class distribution:
#  0: Amphibia - 87 samples (26.2%)
#  1: Aves - 84 samples (25.3%)
#  2: Insecta - 81 samples (24.4%)
#  3: Mammalia - 80 samples (24.1%)
# Imbalance ratio: Aves / Total = 25.30%
#
# Computing balanced class weights...
# Final class weights: {0: 0.9540229885057471, 1: 0.9880952380952381, 2: 1.0246913580246915, 3: 1.0375}
#
# Inspecting one batch from the data generator:
# Batch shape: (32, 256, 256, 1)
# Example batch labels (one-hot): [[1.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00]
#  [5.5861962e-01 0.0000000e+00 0.0000000e+00 4.4138035e-01]
#  [1.2031597e-05 0.0000000e+00 0.0000000e+00 9.9998796e-01]
#  [0.0000000e+00 9.5782000e-01 4.2180005e-02 0.0000000e+00]
#  [0.0000000e+00 7.4239403e-01 2.5760594e-01 0.0000000e+00]
#  [0.0000000e+00 7.2561431e-01 0.0000000e+00 2.7438572e-01]
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 9.9999386e-01 6.1167275e-06]
#  [0.0000000e+00 3.0895357e-08 0.0000000e+00 9.9999994e-01]
#  [4.2623067e-01 0.0000000e+00 0.0000000e+00 5.7376933e-01]
#  [0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00]
#  [6.6705239e-01 0.0000000e+00 3.3294764e-01 0.0000000e+00]
#  [3.2524756e-01 0.0000000e+00 0.0000000e+00 6.7475247e-01]
#  [8.3672857e-01 1.6327140e-01 0.0000000e+00 0.0000000e+00]
#  [9.8935205e-01 1.0647944e-02 0.0000000e+00 0.0000000e+00]
#  [7.6003951e-01 2.3996051e-01 0.0000000e+00 0.0000000e+00]
#  [1.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00]
#  [9.9121195e-01 0.0000000e+00 0.0000000e+00 8.7880595e-03]
#  [0.0000000e+00 1.0000000e+00 0.0000000e+00 0.0000000e+00]
#  [9.9999988e-01 0.0000000e+00 0.0000000e+00 1.2694989e-07]
#  [1.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 4.8770490e-03 9.9512297e-01 0.0000000e+00]
#  [0.0000000e+00 7.1067009e-03 0.0000000e+00 9.9289328e-01]
#  [0.0000000e+00 0.0000000e+00 6.9276132e-02 9.3072385e-01]
#  [1.4392502e-04 0.0000000e+00 9.9985605e-01 0.0000000e+00]
#  [1.0000000e+00 0.0000000e+00 0.0000000e+00 0.0000000e+00]
#  [0.0000000e+00 6.9977355e-01 3.0022642e-01 0.0000000e+00]
#  [0.0000000e+00 3.3906106e-02 0.0000000e+00 9.6609390e-01]
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 1.0000000e+00]
#  [0.0000000e+00 0.0000000e+00 9.4783652e-01 5.2163474e-02]
#  [7.3649067e-01 0.0000000e+00 2.6350933e-01 0.0000000e+00]
#  [0.0000000e+00 6.3632387e-01 3.6367613e-01 0.0000000e+00]]
# Class order: [Amphibia, Aves, Insecta, Mammalia]
#
# Preprocessing metadata with 3D coordinate conversion...
# Metadata feature dimension: 15
#   primary_label             scientific_name                common_name  \
# 0        787625  Leucostethus fraterdanieli     Santa Rita Rocket Frog
# 1         66531      Pristimantis achatinus        Cachabi Robber Frog
# 2        555142                Boana pugnax  Chirique-Flusse Tree Frog
#
#   class_name  longitude  latitude     class  y_species_encoded  split  \
# 0   Amphibia   -75.5153    6.2551  Amphibia                  0  train
# 1   Amphibia   -76.0161    5.7858  Amphibia                  0  train
# 2   Amphibia   -80.9382    8.0390  Amphibia                  0  train
#
#                  filename  has_uncertain category  song/canto   call  \
# 0    787625/iNat48805.ogg          False    other       False  False
# 1    66531/iNat445441.ogg          False    other       False  False
# 2  555142/iNat1258897.ogg          False    other       False  False
#
#    uncertain  mating/groups  hatching  immitation  noise/drum  \
# 0      False          False     False       False       False
# 1      False          False     False       False       False
# 2      False          False     False       False       False
#
#            samplename
# 0    787625-iNat48805
# 1    66531-iNat445441
# 2  555142-iNat1258897

# %%
# Split train / val inside the notebook (80-20 stratified)
train_df, val_df = train_test_split(
    combined_train_val_df,
    test_size=0.20,
    stratify=combined_train_val_df["y_species_encoded"],
    random_state=42,
)

best_model, tuner = run_multimodal_tuner(
    cfg, train_df, val_df,
    filtered_spectrograms,        # you created this earlier
    metadata_features,
    class_weights,
)
# Out:
# Trial 157 Complete [00h 01m 36s]
# val_macro_f1_fn: 0.7408729791641235
#
# Best val_macro_f1_fn So Far: 0.8633597493171692
# Total elapsed time: 09h 31m 26s
# ✅  Search finished!
# Best model saved ➜  /share/crsp/lab/pkaiser/ddlin/mids/DATASCI207_Bird_Sounds/data/working/vit_model_256_aug_cw_tl_tuner/best_vit_model_256_aug_cw_tl.keras
# Best hyperparameters saved to: /share/crsp/lab/pkaiser/ddlin/mids/DATASCI207_Bird_Sounds/data/working/vit_model_256_aug_cw_tl_tuner/best_hps_vit_model_256_aug_cw_tl.json

# %%
best_model.summary()
from tensorflow.keras.utils import plot_model
plot_model(best_model, show_shapes=True, expand_nested=True, dpi=65)
# Out:
# Model: "multimodal_vit"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ meta_input          │ (None, 15)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 128)       │      2,048 │ meta_input[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128)       │        512 │ dense_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ spec_input          │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_13          │ (None, 128)       │          0 │ batch_normalizat… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ vision_branch       │ (None, 768)       │ 85,798,656 │ spec_input[0][0]  │
# │ (Functional)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │      8,256 │ dropout_13[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ fusion_layer        │ (None, 832)       │          0 │ vision_branch[0]… │
# │ (Concatenate)       │                   │            │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 256)       │    213,248 │ fusion_layer[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_14          │ (None, 256)       │          0 │ dense_3[0][0]     │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ final_output        │ (None, 4)         │      1,028 │ dropout_14[0][0]  │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 86,023,748 (328.15 MB)
#  Trainable params: 224,836 (878.27 KB)
#  Non-trainable params: 85,798,912 (327.30 MB)

# %%
hp_json_path = cfg.OUTPUT_DIR / f'{cfg.model_save_name.replace(".keras", "")}_tuner' / f"best_hps_{cfg.model_save_name.replace('.keras', '')}.json"

# ②  Pretty-print them
print("Best hyper-parameters:")
best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]   # <- real H-Ps
for name, val in best_hp.values.items():
    print(f"  {name}: {val}")
# Out:
# Best hyper-parameters:
#   lr: 0.00041424724330521253
#   dropout: 0.30000000000000004
#   vision_lr_mult: 0.25
#   dense_width: 128
#   freeze_epochs: 2
#   weight_decay: 3.390841519182325e-05
#   tuner/epochs: 30
#   tuner/initial_epoch: 10
#   tuner/bracket: 1
#   tuner/round: 1
#   tuner/trial_id: 0145

# %%
# Check if we have already trained the 5-fold model
if cfg.train_model:
    print("Training model with best hyperparameters - 5-fold cross-validation")
    metrics = cross_validate_best_hp(
        cfg                 = cfg,
        full_df             = combined_train_val_df,   # or whatever split you want
        spectrograms        = filtered_spectrograms,
        metadata_features   = metadata_features,
        class_weights       = class_weights,
        hp_json_path        = hp_json_path,
        n_splits            = cfg.n_fold,
    )
# Out:
# Training model with best hyperparameters - 5-fold cross-validation
#
# ==========  Fold 1/5  ==========
# [INFO] Unfroze backbone with 4 sub-layers.
# [WARN] Could not scale LR — unrecognised type: <class 'tensorflow.python.framework.ops.EagerTensor'>
# Epoch 1/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 40s 349ms/step - accuracy: 0.3680 - loss: 0.1893 - macro_f1_fn: 0.2861 - val_accuracy: 0.2361 - val_loss: 0.1978 - val_macro_f1_fn: 0.0933
# Epoch 2/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 295ms/step - accuracy: 0.5037 - loss: 0.1234 - macro_f1_fn: 0.4059 - val_accuracy: 0.3333 - val_loss: 0.1841 - val_macro_f1_fn: 0.1838
# [INFO] Unfroze backbone with 4 sub-layers.
# [WARN] Could not scale LR — unrecognised type: <class 'tensorflow.python.framework.ops.EagerTensor'>
# Epoch 3/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 149ms/step - accuracy: 0.5728 - loss: 0.1202 - macro_f1_fn: 0.4813 - val_accuracy: 0.2917 - val_loss: 0.1807 - val_macro_f1_fn: 0.1529
# Epoch 4/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 325ms/step - accuracy: 0.5564 - loss: 0.1121 - macro_f1_fn: 0.4798 - val_accuracy: 0.3889 - val_loss: 0.1687 - val_macro_f1_fn: 0.2663
# Epoch 5/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 302ms/step - accuracy: 0.5627 - loss: 0.1128 - macro_f1_fn: 0.5241 - val_accuracy: 0.6111 - val_loss: 0.1648 - val_macro_f1_fn: 0.5153
# Epoch 6/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.6542 - loss: 0.1060 - macro_f1_fn: 0.5693 - val_accuracy: 0.5139 - val_loss: 0.1627 - val_macro_f1_fn: 0.4196
# Epoch 7/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 299ms/step - accuracy: 0.5952 - loss: 0.1142 - macro_f1_fn: 0.5257 - val_accuracy: 0.6111 - val_loss: 0.1579 - val_macro_f1_fn: 0.5212
# Epoch 8/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 157ms/step - accuracy: 0.6621 - loss: 0.1091 - macro_f1_fn: 0.5519 - val_accuracy: 0.6111 - val_loss: 0.1410 - val_macro_f1_fn: 0.5174
# Epoch 9/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 292ms/step - accuracy: 0.6309 - loss: 0.1139 - macro_f1_fn: 0.5384 - val_accuracy: 0.6528 - val_loss: 0.1532 - val_macro_f1_fn: 0.5400
# Epoch 10/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 277ms/step - accuracy: 0.6071 - loss: 0.0930 - macro_f1_fn: 0.5401 - val_accuracy: 0.6667 - val_loss: 0.1533 - val_macro_f1_fn: 0.5782
# Epoch 11/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 281ms/step - accuracy: 0.7203 - loss: 0.0869 - macro_f1_fn: 0.6508 - val_accuracy: 0.7222 - val_loss: 0.1503 - val_macro_f1_fn: 0.6431
# Epoch 12/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.6678 - loss: 0.0906 - macro_f1_fn: 0.5930 - val_accuracy: 0.6389 - val_loss: 0.1564 - val_macro_f1_fn: 0.5968
# Epoch 13/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.6722 - loss: 0.0889 - macro_f1_fn: 0.6022 - val_accuracy: 0.6667 - val_loss: 0.1790 - val_macro_f1_fn: 0.5978
# Epoch 14/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 140ms/step - accuracy: 0.6932 - loss: 0.0863 - macro_f1_fn: 0.5812 - val_accuracy: 0.6389 - val_loss: 0.1634 - val_macro_f1_fn: 0.5679
# Epoch 15/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 290ms/step - accuracy: 0.6540 - loss: 0.1034 - macro_f1_fn: 0.5525 - val_accuracy: 0.7500 - val_loss: 0.1104 - val_macro_f1_fn: 0.6872
#
# ==========  Fold 2/5  ==========
# [INFO] Unfroze backbone with 4 sub-layers.
# [WARN] Could not scale LR — unrecognised type: <class 'tensorflow.python.framework.ops.EagerTensor'>
# Epoch 1/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 39s 330ms/step - accuracy: 0.2961 - loss: 0.1973 - macro_f1_fn: 0.1922 - val_accuracy: 0.2361 - val_loss: 0.1852 - val_macro_f1_fn: 0.0902
# Epoch 2/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 278ms/step - accuracy: 0.5293 - loss: 0.1337 - macro_f1_fn: 0.4426 - val_accuracy: 0.3889 - val_loss: 0.1687 - val_macro_f1_fn: 0.2506
# [INFO] Unfroze backbone with 4 sub-layers.
# [WARN] Could not scale LR — unrecognised type: <class 'tensorflow.python.framework.ops.EagerTensor'>
# Epoch 3/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 162ms/step - accuracy: 0.5809 - loss: 0.1255 - macro_f1_fn: 0.5628 - val_accuracy: 0.3333 - val_loss: 0.1789 - val_macro_f1_fn: 0.2142
# Epoch 4/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 270ms/step - accuracy: 0.5287 - loss: 0.1281 - macro_f1_fn: 0.4564 - val_accuracy: 0.5000 - val_loss: 0.1555 - val_macro_f1_fn: 0.3146
# Epoch 5/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 306ms/step - accuracy: 0.6187 - loss: 0.1037 - macro_f1_fn: 0.5553 - val_accuracy: 0.5694 - val_loss: 0.1408 - val_macro_f1_fn: 0.4489
# Epoch 6/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 285ms/step - accuracy: 0.6765 - loss: 0.1051 - macro_f1_fn: 0.5908 - val_accuracy: 0.7500 - val_loss: 0.1208 - val_macro_f1_fn: 0.6446
# Epoch 7/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 289ms/step - accuracy: 0.6888 - loss: 0.0917 - macro_f1_fn: 0.6421 - val_accuracy: 0.7361 - val_loss: 0.1150 - val_macro_f1_fn: 0.6524
# Epoch 8/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 300ms/step - accuracy: 0.6855 - loss: 0.1091 - macro_f1_fn: 0.5602 - val_accuracy: 0.7361 - val_loss: 0.1088 - val_macro_f1_fn: 0.6701
# Epoch 9/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 304ms/step - accuracy: 0.6540 - loss: 0.1089 - macro_f1_fn: 0.5921 - val_accuracy: 0.7778 - val_loss: 0.1026 - val_macro_f1_fn: 0.6757
# Epoch 10/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 279ms/step - accuracy: 0.6495 - loss: 0.1083 - macro_f1_fn: 0.5722 - val_accuracy: 0.7917 - val_loss: 0.0811 - val_macro_f1_fn: 0.7078
# Epoch 11/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 135ms/step - accuracy: 0.7102 - loss: 0.0947 - macro_f1_fn: 0.6308 - val_accuracy: 0.7222 - val_loss: 0.0985 - val_macro_f1_fn: 0.5634
# Epoch 12/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 287ms/step - accuracy: 0.7211 - loss: 0.0934 - macro_f1_fn: 0.6141 - val_accuracy: 0.8056 - val_loss: 0.0737 - val_macro_f1_fn: 0.7749
# Epoch 13/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.6397 - loss: 0.1064 - macro_f1_fn: 0.5531 - val_accuracy: 0.8611 - val_loss: 0.0788 - val_macro_f1_fn: 0.7670
# Epoch 14/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 292ms/step - accuracy: 0.6745 - loss: 0.1032 - macro_f1_fn: 0.6105 - val_accuracy: 0.8750 - val_loss: 0.0692 - val_macro_f1_fn: 0.7992
# Epoch 15/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.6556 - loss: 0.0953 - macro_f1_fn: 0.6003 - val_accuracy: 0.8472 - val_loss: 0.0719 - val_macro_f1_fn: 0.7779
#
# ==========  Fold 3/5  ==========
# [INFO] Unfroze backbone with 4 sub-layers.
# [WARN] Could not scale LR — unrecognised type: <class 'tensorflow.python.framework.ops.EagerTensor'>
# Epoch 1/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 38s 333ms/step - accuracy: 0.3205 - loss: 0.1976 - macro_f1_fn: 0.2314 - val_accuracy: 0.2639 - val_loss: 0.1845 - val_macro_f1_fn: 0.1029
# Epoch 2/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 277ms/step - accuracy: 0.5101 - loss: 0.1411 - macro_f1_fn: 0.4326 - val_accuracy: 0.5417 - val_loss: 0.1688 - val_macro_f1_fn: 0.4346
# [INFO] Unfroze backbone with 4 sub-layers.
# [WARN] Could not scale LR — unrecognised type: <class 'tensorflow.python.framework.ops.EagerTensor'>
# Epoch 3/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 165ms/step - accuracy: 0.6092 - loss: 0.1066 - macro_f1_fn: 0.5445 - val_accuracy: 0.5139 - val_loss: 0.1587 - val_macro_f1_fn: 0.4262
# Epoch 4/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 152ms/step - accuracy: 0.6157 - loss: 0.1100 - macro_f1_fn: 0.5418 - val_accuracy: 0.5278 - val_loss: 0.1573 - val_macro_f1_fn: 0.3947
# Epoch 5/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 271ms/step - accuracy: 0.6490 - loss: 0.1117 - macro_f1_fn: 0.5514 - val_accuracy: 0.7222 - val_loss: 0.1482 - val_macro_f1_fn: 0.6193
# Epoch 6/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 306ms/step - accuracy: 0.6286 - loss: 0.1109 - macro_f1_fn: 0.5855 - val_accuracy: 0.7639 - val_loss: 0.1284 - val_macro_f1_fn: 0.6771
# Epoch 7/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.6712 - loss: 0.0995 - macro_f1_fn: 0.5659 - val_accuracy: 0.7083 - val_loss: 0.1328 - val_macro_f1_fn: 0.6307
# Epoch 8/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 287ms/step - accuracy: 0.6937 - loss: 0.0882 - macro_f1_fn: 0.6205 - val_accuracy: 0.7500 - val_loss: 0.1283 - val_macro_f1_fn: 0.6997
# Epoch 9/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 168ms/step - accuracy: 0.6950 - loss: 0.0881 - macro_f1_fn: 0.6010 - val_accuracy: 0.7083 - val_loss: 0.1203 - val_macro_f1_fn: 0.6266
# Epoch 10/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.6252 - loss: 0.1045 - macro_f1_fn: 0.5214 - val_accuracy: 0.6944 - val_loss: 0.1176 - val_macro_f1_fn: 0.6017
# Epoch 11/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - accuracy: 0.6702 - loss: 0.0900 - macro_f1_fn: 0.5748 - val_accuracy: 0.6667 - val_loss: 0.1200 - val_macro_f1_fn: 0.6200
# Epoch 12/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - accuracy: 0.6893 - loss: 0.1002 - macro_f1_fn: 0.6039 - val_accuracy: 0.7222 - val_loss: 0.1106 - val_macro_f1_fn: 0.5983
#
# ==========  Fold 4/5  ==========
# [INFO] Unfroze backbone with 4 sub-layers.
# [WARN] Could not scale LR — unrecognised type: <class 'tensorflow.python.framework.ops.EagerTensor'>
# Epoch 1/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 37s 322ms/step - accuracy: 0.3369 - loss: 0.1706 - macro_f1_fn: 0.2330 - val_accuracy: 0.2639 - val_loss: 0.1810 - val_macro_f1_fn: 0.1173
# Epoch 2/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 294ms/step - accuracy: 0.4782 - loss: 0.1402 - macro_f1_fn: 0.3918 - val_accuracy: 0.4028 - val_loss: 0.1650 - val_macro_f1_fn: 0.2292
# [INFO] Unfroze backbone with 4 sub-layers.
# [WARN] Could not scale LR — unrecognised type: <class 'tensorflow.python.framework.ops.EagerTensor'>
# Epoch 3/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 11s 315ms/step - accuracy: 0.5563 - loss: 0.1246 - macro_f1_fn: 0.4793 - val_accuracy: 0.4583 - val_loss: 0.1553 - val_macro_f1_fn: 0.3183
# Epoch 4/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 274ms/step - accuracy: 0.6097 - loss: 0.1111 - macro_f1_fn: 0.5294 - val_accuracy: 0.5139 - val_loss: 0.1447 - val_macro_f1_fn: 0.3453
# Epoch 5/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 170ms/step - accuracy: 0.5581 - loss: 0.1212 - macro_f1_fn: 0.4669 - val_accuracy: 0.5139 - val_loss: 0.1400 - val_macro_f1_fn: 0.3236
# Epoch 6/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 276ms/step - accuracy: 0.6259 - loss: 0.1025 - macro_f1_fn: 0.4866 - val_accuracy: 0.7639 - val_loss: 0.1326 - val_macro_f1_fn: 0.5755
# Epoch 7/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 166ms/step - accuracy: 0.6870 - loss: 0.0955 - macro_f1_fn: 0.5936 - val_accuracy: 0.5139 - val_loss: 0.1235 - val_macro_f1_fn: 0.3354
# Epoch 8/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 136ms/step - accuracy: 0.5825 - loss: 0.1130 - macro_f1_fn: 0.5498 - val_accuracy: 0.6944 - val_loss: 0.1190 - val_macro_f1_fn: 0.5047
# Epoch 9/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 293ms/step - accuracy: 0.6178 - loss: 0.1038 - macro_f1_fn: 0.5767 - val_accuracy: 0.7778 - val_loss: 0.1070 - val_macro_f1_fn: 0.5925
# Epoch 10/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 280ms/step - accuracy: 0.7113 - loss: 0.1012 - macro_f1_fn: 0.5851 - val_accuracy: 0.7500 - val_loss: 0.1086 - val_macro_f1_fn: 0.6310
# Epoch 11/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 281ms/step - accuracy: 0.6592 - loss: 0.0886 - macro_f1_fn: 0.5740 - val_accuracy: 0.8056 - val_loss: 0.0865 - val_macro_f1_fn: 0.6725
# Epoch 12/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 275ms/step - accuracy: 0.7198 - loss: 0.0774 - macro_f1_fn: 0.6776 - val_accuracy: 0.8056 - val_loss: 0.0949 - val_macro_f1_fn: 0.7019
# Epoch 13/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 165ms/step - accuracy: 0.6606 - loss: 0.1024 - macro_f1_fn: 0.5747 - val_accuracy: 0.7917 - val_loss: 0.0787 - val_macro_f1_fn: 0.6595
# Epoch 14/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - accuracy: 0.7198 - loss: 0.0987 - macro_f1_fn: 0.6214 - val_accuracy: 0.7639 - val_loss: 0.0938 - val_macro_f1_fn: 0.6220
# Epoch 15/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 151ms/step - accuracy: 0.7001 - loss: 0.0875 - macro_f1_fn: 0.6119 - val_accuracy: 0.8194 - val_loss: 0.0712 - val_macro_f1_fn: 0.6947
#
# ==========  Fold 5/5  ==========
# [INFO] Unfroze backbone with 4 sub-layers.
# [WARN] Could not scale LR — unrecognised type: <class 'tensorflow.python.framework.ops.EagerTensor'>
# Epoch 1/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 38s 332ms/step - accuracy: 0.3365 - loss: 0.1916 - macro_f1_fn: 0.2636 - val_accuracy: 0.3194 - val_loss: 0.1913 - val_macro_f1_fn: 0.1782
# Epoch 2/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 154ms/step - accuracy: 0.5349 - loss: 0.1248 - macro_f1_fn: 0.4792 - val_accuracy: 0.2361 - val_loss: 0.1810 - val_macro_f1_fn: 0.0917
# [INFO] Unfroze backbone with 4 sub-layers.
# [WARN] Could not scale LR — unrecognised type: <class 'tensorflow.python.framework.ops.EagerTensor'>
# Epoch 3/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 280ms/step - accuracy: 0.5848 - loss: 0.1189 - macro_f1_fn: 0.4335 - val_accuracy: 0.3889 - val_loss: 0.1696 - val_macro_f1_fn: 0.2452
# Epoch 4/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 290ms/step - accuracy: 0.6372 - loss: 0.1056 - macro_f1_fn: 0.6017 - val_accuracy: 0.4722 - val_loss: 0.1525 - val_macro_f1_fn: 0.3565
# Epoch 5/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 296ms/step - accuracy: 0.5841 - loss: 0.1219 - macro_f1_fn: 0.4910 - val_accuracy: 0.5278 - val_loss: 0.1568 - val_macro_f1_fn: 0.3837
# Epoch 6/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 279ms/step - accuracy: 0.6246 - loss: 0.1055 - macro_f1_fn: 0.5518 - val_accuracy: 0.6944 - val_loss: 0.1273 - val_macro_f1_fn: 0.5787
# Epoch 7/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 277ms/step - accuracy: 0.6410 - loss: 0.1004 - macro_f1_fn: 0.5823 - val_accuracy: 0.7083 - val_loss: 0.1258 - val_macro_f1_fn: 0.6027
# Epoch 8/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 166ms/step - accuracy: 0.6467 - loss: 0.0938 - macro_f1_fn: 0.6051 - val_accuracy: 0.6806 - val_loss: 0.1141 - val_macro_f1_fn: 0.5854
# Epoch 9/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 293ms/step - accuracy: 0.6531 - loss: 0.1085 - macro_f1_fn: 0.5525 - val_accuracy: 0.7361 - val_loss: 0.1134 - val_macro_f1_fn: 0.6031
# Epoch 10/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 134ms/step - accuracy: 0.6819 - loss: 0.0973 - macro_f1_fn: 0.6066 - val_accuracy: 0.6806 - val_loss: 0.1108 - val_macro_f1_fn: 0.5825
# Epoch 11/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 294ms/step - accuracy: 0.6910 - loss: 0.0866 - macro_f1_fn: 0.6409 - val_accuracy: 0.6944 - val_loss: 0.1107 - val_macro_f1_fn: 0.6415
# Epoch 12/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 162ms/step - accuracy: 0.7163 - loss: 0.0941 - macro_f1_fn: 0.6691 - val_accuracy: 0.7361 - val_loss: 0.1003 - val_macro_f1_fn: 0.6132
# Epoch 13/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 9s 278ms/step - accuracy: 0.7211 - loss: 0.0960 - macro_f1_fn: 0.6330 - val_accuracy: 0.7917 - val_loss: 0.0814 - val_macro_f1_fn: 0.7279
# Epoch 14/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 6s 162ms/step - accuracy: 0.6689 - loss: 0.0988 - macro_f1_fn: 0.5466 - val_accuracy: 0.7222 - val_loss: 0.1073 - val_macro_f1_fn: 0.5800
# Epoch 15/15
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 5s 137ms/step - accuracy: 0.6943 - loss: 0.1057 - macro_f1_fn: 0.6051 - val_accuracy: 0.7917 - val_loss: 0.0895 - val_macro_f1_fn: 0.7136
#
# ===== CV summary =====
#          fold  best_epoch  val_loss  val_accuracy  val_macro_f1
# count  5.0000      5.0000    5.0000        5.0000        5.0000
# mean   3.0000     11.4000    0.0968        0.7944        0.7232
# std    1.5811      2.7019    0.0233        0.0514        0.0450
# min    1.0000      7.0000    0.0692        0.7500        0.6872
# 25%    2.0000     11.0000    0.0814        0.7500        0.6997
# 50%    3.0000     12.0000    0.0949        0.7917        0.7019
# 75%    4.0000     13.0000    0.1104        0.8056        0.7279
# max    5.0000     14.0000    0.1283        0.8750        0.7992

# %%
# from project_utils.model_architect import macro_f1_fn, categorical_focal_loss, UnfreezeBackbone, AddClsToken, SpecTimeMask, SpecFreqMask

custom_objects = {
    'macro_f1_fn': macro_f1_fn,
    'categorical_focal_loss_a0.25_g2.0': categorical_focal_loss(alpha=0.25, gamma=2.0),  # Key now matches the saved name; adjust alpha/gamma only if they were tuned differently
    'AddClsToken': AddClsToken,
    'UnfreezeBackbone': UnfreezeBackbone,
    'SpecTimeMask': SpecTimeMask,
    'SpecFreqMask': SpecFreqMask,
}

# Save the y_pred_prob and y_true from the test set
y_pred_prob_list = []

for fold in range(1, cfg.n_fold + 1):  # Loop over all folds (1 to n_fold)
    # Load the best model for each fold
    fold_model_name = f'{cfg.model_save_name.replace(".keras", "")}_fold{fold}.keras'
    model_path = cfg.MODELS_DIR / fold_model_name
    
    print(f"Loading model for fold {fold} from {model_path}")
    fold_model = keras.models.load_model(
        model_path,
        custom_objects=custom_objects,
        compile=True,          # or False and re-compile later
        safe_mode=False
    )
    print(f"Model for fold {fold} loaded successfully.")

    # Evaluate on test set
    y_true, y_pred_prob = evaluate_on_test_multimodal(
        model=fold_model,
        cfg=cfg,
        spectrograms=filtered_spectrograms,
        metadata_features=metadata_features,
        test_df=test_df,
    )
    y_pred_prob_list.append(y_pred_prob)
# Out:
# Loading model for fold 1 from /share/crsp/lab/pkaiser/ddlin/mids/DATASCI207_Bird_Sounds/data/working/models/vit_model_256_aug_cw_tl_fold1.keras
# Model for fold 1 loaded successfully.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 92ms/step
#
# Test Loss: 1.4388
# Test AUC: 0.4410
# Test Accuracy: 0.1912
# Loading model for fold 2 from /share/crsp/lab/pkaiser/ddlin/mids/DATASCI207_Bird_Sounds/data/working/models/vit_model_256_aug_cw_tl_fold2.keras
# Model for fold 2 loaded successfully.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 103ms/step
#
# Test Loss: 1.4579
# Test AUC: 0.4553
# Test Accuracy: 0.1912
# Loading model for fold 3 from /share/crsp/lab/pkaiser/ddlin/mids/DATASCI207_Bird_Sounds/data/working/models/vit_model_256_aug_cw_tl_fold3.keras
# Model for fold 3 loaded successfully.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 106ms/step
#
# Test Loss: 1.4376
# Test AUC: 0.4918
# Test Accuracy: 0.2353
# Loading model for fold 4 from /share/crsp/lab/pkaiser/ddlin/mids/DATASCI207_Bird_Sounds/data/working/models/vit_model_256_aug_cw_tl_fold4.keras
# Model for fold 4 loaded successfully.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 104ms/step
#
# Test Loss: 1.4053
# Test AUC: 0.4859
# Test Accuracy: 0.1912
# Loading model for fold 5 from /share/crsp/lab/pkaiser/ddlin/mids/DATASCI207_Bird_Sounds/data/working/models/vit_model_256_aug_cw_tl_fold5.keras
# Model for fold 5 loaded successfully.
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
#
# Test Loss: 1.3890
# Test AUC: 0.5033
# Test Accuracy: 0.2794

# %%
# Convert list to numpy array for easier handling
y_pred_prob = np.array(y_pred_prob_list).mean(axis=0)

# Plot training diagnostics
plot_test_evaluation(y_true, y_pred_prob, class_mapping=CLASS_MAPPING_DICT, cfg=cfg)
# Out:
# Test evaluation plot saved to: /share/crsp/lab/pkaiser/ddlin/mids/DATASCI207_Bird_Sounds/data/working/plots/test_evaluation_256vit_model_256_aug_cw_tl.png
# Classification report saved to: /share/crsp/lab/pkaiser/ddlin/mids/DATASCI207_Bird_Sounds/data/working/result_csvs/classification_report_256vit_model_256_aug_cw_tl.csv
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Amphibia       0.19      1.00      0.32        13
#         Aves       0.00      0.00      0.00        16
#      Insecta       0.00      0.00      0.00        19
#     Mammalia       0.00      0.00      0.00        20
#
#     accuracy                           0.19        68
#    macro avg       0.05      0.25      0.08        68
# weighted avg       0.04      0.19      0.06        68

# %%
import tensorflow.keras.metrics as kmetrics
# Set up from scratch using these hp
# Best hyper-parameters:
#   lr: 0.00041424724330521253
#   dropout: 0.30000000000000004
#   vision_lr_mult: 0.25
#   dense_width: 128
#   freeze_epochs: 2
#   weight_decay: 3.390841519182325e-05
#   tuner/epochs: 30
#   tuner/initial_epoch: 10
#   tuner/bracket: 1
#   tuner/round: 1
#   tuner/trial_id: 0145

cfg.lr       = 4.142472433052125e-05  # tuned
cfg.min_lr   = 1.0e-06                  # 1 % of lr
cfg.epochs   = 30                      # from tuner
cfg.weight_decay = 3.390841519182325e-06  # tuned
cfg.freeze_epochs = 2                  # from tuner
cfg.dropout_rate = 0.3                # from tuner
cfg.vision_lr_mult = 0.25              # from tuner

# Create the model with the best hyperparameters
cosine_scheduler = get_cosine_decay_scheduler(train_df, cfg)

model = get_multimodal_vit_model(cfg=cfg)

model.compile(
    optimizer = keras.optimizers.AdamW(
        learning_rate=cosine_scheduler,  # Use scheduler instead of fixed lr
        weight_decay=cfg.weight_decay
    ),
    loss      = categorical_focal_loss(alpha=0.25, gamma=2.0),  # Use the tuned focal loss
    metrics   = [
        "accuracy",
        macro_f1_fn,
        kmetrics.AUC(name="auroc", multi_label=True, from_logits=False)
    ],
)

train_df, val_df = train_test_split(
    combined_train_val_df,
    test_size=0.20,
    stratify=combined_train_val_df["y_species_encoded"],
    random_state=42,
)

# Compute fixed data generators and steps outside (HP-independent)
train_gen = data_generator_with_metadata(
    train_df, cfg, filtered_spectrograms, metadata_features,
    class_weights=class_weights,
    is_train=True,
    yield_weight=False,
    batch_size=cfg.batch_size,
)
val_gen = data_generator_with_metadata(
    val_df, cfg, filtered_spectrograms, metadata_features,
    class_weights=None,
    is_train=False,
    yield_weight=False,
    batch_size=cfg.batch_size,
)

steps_per_epoch = get_steps(train_df, cfg, cfg.batch_size)
val_steps = get_steps(val_df, cfg, cfg.batch_size)

callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss', patience=3, restore_best_weights=True
    ),
    # UnfreezeBackbone(           # ← no verbose kwarg
    #     freeze_epochs = cfg.freeze_epochs,
    #     lr_mult       = cfg.vision_lr_mult,   # don’t forget this
    #     key           = "vi_t_backbone",
    # ),
]


history = model.fit(
    train_gen,
    steps_per_epoch = steps_per_epoch,
    validation_data = val_gen,
    validation_steps= val_steps,
    epochs          = cfg.epochs,
    callbacks       = callbacks,
    verbose         = 1,
)
# Out:
# Epoch 1/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 10s 96ms/step - accuracy: 0.1827 - auroc: 0.4300 - loss: 0.2424 - macro_f1_fn: 0.1159 - val_accuracy: 0.2917 - val_auroc: 0.5101 - val_loss: 0.1997 - val_macro_f1_fn: 0.2107
# Epoch 2/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - accuracy: 0.2299 - auroc: 0.4730 - loss: 0.2102 - macro_f1_fn: 0.1679 - val_accuracy: 0.3194 - val_auroc: 0.4548 - val_loss: 0.1986 - val_macro_f1_fn: 0.1873
# Epoch 3/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.2922 - auroc: 0.5541 - loss: 0.1893 - macro_f1_fn: 0.2387 - val_accuracy: 0.3472 - val_auroc: 0.6181 - val_loss: 0.1875 - val_macro_f1_fn: 0.2411
# Epoch 4/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.3191 - auroc: 0.5359 - loss: 0.1833 - macro_f1_fn: 0.2777 - val_accuracy: 0.3472 - val_auroc: 0.6041 - val_loss: 0.1861 - val_macro_f1_fn: 0.2056
# Epoch 5/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.3393 - auroc: 0.5567 - loss: 0.1678 - macro_f1_fn: 0.2547 - val_accuracy: 0.3750 - val_auroc: 0.6463 - val_loss: 0.1838 - val_macro_f1_fn: 0.2717
# Epoch 6/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.4073 - auroc: 0.6072 - loss: 0.1600 - macro_f1_fn: 0.3106 - val_accuracy: 0.4167 - val_auroc: 0.6771 - val_loss: 0.1751 - val_macro_f1_fn: 0.2789
# Epoch 7/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.4026 - auroc: 0.5528 - loss: 0.1626 - macro_f1_fn: 0.3628 - val_accuracy: 0.5000 - val_auroc: 0.7542 - val_loss: 0.1658 - val_macro_f1_fn: 0.3684
# Epoch 8/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.4168 - auroc: 0.6077 - loss: 0.1549 - macro_f1_fn: 0.3568 - val_accuracy: 0.5000 - val_auroc: 0.7472 - val_loss: 0.1672 - val_macro_f1_fn: 0.4579
# Epoch 9/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.4440 - auroc: 0.6137 - loss: 0.1486 - macro_f1_fn: 0.3608 - val_accuracy: 0.5278 - val_auroc: 0.7712 - val_loss: 0.1610 - val_macro_f1_fn: 0.4598
# Epoch 10/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.5173 - auroc: 0.6347 - loss: 0.1432 - macro_f1_fn: 0.4438 - val_accuracy: 0.5694 - val_auroc: 0.8063 - val_loss: 0.1552 - val_macro_f1_fn: 0.5051
# Epoch 11/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 45ms/step - accuracy: 0.5121 - auroc: 0.7060 - loss: 0.1314 - macro_f1_fn: 0.4439 - val_accuracy: 0.5000 - val_auroc: 0.7934 - val_loss: 0.1543 - val_macro_f1_fn: 0.4178
# Epoch 12/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 77ms/step - accuracy: 0.5512 - auroc: 0.6609 - loss: 0.1234 - macro_f1_fn: 0.4847 - val_accuracy: 0.5972 - val_auroc: 0.7942 - val_loss: 0.1506 - val_macro_f1_fn: 0.5082
# Epoch 13/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 75ms/step - accuracy: 0.5033 - auroc: 0.6606 - loss: 0.1355 - macro_f1_fn: 0.4234 - val_accuracy: 0.6250 - val_auroc: 0.8262 - val_loss: 0.1413 - val_macro_f1_fn: 0.5106
# Epoch 14/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.5357 - auroc: 0.6545 - loss: 0.1290 - macro_f1_fn: 0.4932 - val_accuracy: 0.6389 - val_auroc: 0.8327 - val_loss: 0.1429 - val_macro_f1_fn: 0.5678
# Epoch 15/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.5563 - auroc: 0.6690 - loss: 0.1247 - macro_f1_fn: 0.4853 - val_accuracy: 0.6667 - val_auroc: 0.8654 - val_loss: 0.1272 - val_macro_f1_fn: 0.5882
# Epoch 16/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - accuracy: 0.6648 - auroc: 0.7137 - loss: 0.1098 - macro_f1_fn: 0.5928 - val_accuracy: 0.6528 - val_auroc: 0.8458 - val_loss: 0.1319 - val_macro_f1_fn: 0.5884
# Epoch 17/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 43ms/step - accuracy: 0.5343 - auroc: 0.6792 - loss: 0.1311 - macro_f1_fn: 0.4403 - val_accuracy: 0.6389 - val_auroc: 0.8422 - val_loss: 0.1273 - val_macro_f1_fn: 0.4979
# Epoch 18/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 79ms/step - accuracy: 0.5367 - auroc: 0.6960 - loss: 0.1226 - macro_f1_fn: 0.4627 - val_accuracy: 0.6806 - val_auroc: 0.8750 - val_loss: 0.1213 - val_macro_f1_fn: 0.6064
# Epoch 19/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.5563 - auroc: 0.6967 - loss: 0.1245 - macro_f1_fn: 0.4757 - val_accuracy: 0.6667 - val_auroc: 0.8734 - val_loss: 0.1172 - val_macro_f1_fn: 0.6369
# Epoch 20/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - accuracy: 0.5563 - auroc: 0.6844 - loss: 0.1200 - macro_f1_fn: 0.4910 - val_accuracy: 0.6389 - val_auroc: 0.8535 - val_loss: 0.1234 - val_macro_f1_fn: 0.5291
# Epoch 21/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.6588 - auroc: 0.7137 - loss: 0.1081 - macro_f1_fn: 0.5952 - val_accuracy: 0.6250 - val_auroc: 0.8533 - val_loss: 0.1239 - val_macro_f1_fn: 0.5264
# Epoch 22/30
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 3s 76ms/step - accuracy: 0.5217 - auroc: 0.6573 - loss: 0.1241 - macro_f1_fn: 0.4638 - val_accuracy: 0.6389 - val_auroc: 0.8608 - val_loss: 0.1243 - val_macro_f1_fn: 0.5043

# %%
y_true, y_pred_prob = evaluate_on_test_multimodal(
    model=model,
    cfg=cfg,
    spectrograms=filtered_spectrograms,
    metadata_features=metadata_features,
    test_df=test_df,
)

# Plot training diagnostics
plot_training_diagnostics(history, cfg,  y_true, y_pred_prob, CLASS_MAPPING_DICT)
plot_test_evaluation(y_true, y_pred_prob, class_mapping=CLASS_MAPPING_DICT, cfg=cfg)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step
#
# Test Loss: 1.4060
# Test AUC: 0.4804
# Test Accuracy: 0.2206
# Training curves saved to: /share/crsp/lab/pkaiser/ddlin/mids/DATASCI207_Bird_Sounds/data/working/plots/training_curves_256vit_model_256_aug_cw_tl.png
# Confusion matrix saved to: /share/crsp/lab/pkaiser/ddlin/mids/DATASCI207_Bird_Sounds/data/working/plots/confusion_matrix_256vit_model_256_aug_cw_tl.png
# Per-class metrics saved to: /share/crsp/lab/pkaiser/ddlin/mids/DATASCI207_Bird_Sounds/data/working/plots/per_class_metrics_256vit_model_256_aug_cw_tl.png
# Test evaluation plot saved to: /share/crsp/lab/pkaiser/ddlin/mids/DATASCI207_Bird_Sounds/data/working/plots/test_evaluation_256vit_model_256_aug_cw_tl.png
# Classification report saved to: /share/crsp/lab/pkaiser/ddlin/mids/DATASCI207_Bird_Sounds/data/working/result_csvs/classification_report_256vit_model_256_aug_cw_tl.csv
#
# Classification Report:
#               precision    recall  f1-score   support
#
#     Amphibia       0.17      0.31      0.22        13
#         Aves       0.19      0.44      0.27        16
#      Insecta       0.20      0.05      0.08        19
#     Mammalia       0.75      0.15      0.25        20
#
#     accuracy                           0.22        68
#    macro avg       0.33      0.24      0.21        68
# weighted avg       0.36      0.22      0.20        68
